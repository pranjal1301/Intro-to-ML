# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('crime.csv')
df.head(5)

# %%
df = df.drop(['Title','Text'], axis=1)
df.head(20)

# %%
df = df.fillna(0)
col = df.columns
df.columns = [i for i in range(0,len(col))] 
df.head(20)

# %%
d={0:0,'Property Disputes':1,'Family Dispute':2,'Petty Quarrels':3,'Money Disputes':4, 'Personal Vendetta':5, 'Love Affairs':6, 'Casteism':7,'Unknown reasons':8}
df[1]=df[1].apply(lambda x : d[x])
df.head(20)

# %%
df[11]=0
df[12]=0
df.head(5)

# %%
for i in range(0,len(df)):
    if ',' in str(df.iloc[i,8]):
        cl=df.iloc[i,8].split(',')
        df.iloc[i,8]=int(cl[0])
        df.iloc[i,11]=int(cl[1])
        if len(cl)>2:
            df.iloc[i,12]=int(cl[2])
    elif int(df.iloc[i,8])>100:
        df.iloc[i,11]=int(df.iloc[i,8])%100
        df.iloc[i,8]=int(df.iloc[i,8])//100
df.head(5)

# %%
df.groupby([0]).sum()

# %%
df.describe()

# %%
df[1].value_counts()

# %%
arr1 = np.array(df[6])

# %%
plt.hist(arr1)

# %%
arr2 = np.array(df[7])
plt.hist(arr2)

# %%
count1=0
count2=0
count3=0
count4=0
for i in range(len(df)) :
    if df.iloc[i, 0]=="Ghaziabad":
        count1=count1+df.iloc[i,2]+df.iloc[i,3]+df.iloc[i,4]
    elif df.iloc[i, 0]=="Kanpur":
        count2=count2+df.iloc[i,2]+df.iloc[i,3]+df.iloc[i,4]
    elif df.iloc[i, 0]=="Lucknow":
        count3=count3+df.iloc[i,2]+df.iloc[i,3]+df.iloc[i,4]
    else:
        count4=count4+df.iloc[i,2]+df.iloc[i,3]+df.iloc[i,4]
city=list(("Ghaziabad","Kanpur","Lucknow","Others"))     
count=list((count1,count2,count3,count4))  
plt.bar(city, count, color ='purple',width = 0.5)
 
plt.xlabel("City")
plt.ylabel("All Possible Victims")
plt.title("Murder")
plt.show()

# %%
count1=0
count2=0
count3=0
count4=0
for i in range(len(df)) :
    if df.iloc[i, 0]=="Ghaziabad":
        count1=count1+df.iloc[i,5]+df.iloc[i,6]+df.iloc[i,7]
    elif df.iloc[i, 0]=="Kanpur":
        count2=count2+df.iloc[i,5]+df.iloc[i,6]+df.iloc[i,7]
    elif df.iloc[i, 0]=="Lucknow":
        count3=count3+df.iloc[i,5]+df.iloc[i,6]+df.iloc[i,7]
    else:
        count4=count4+df.iloc[i,5]+df.iloc[i,6]+df.iloc[i,7]
city=list(("Ghaziabad","Kanpur","Lucknow","Others"))     
count=list((count1,count2,count3,count4))  
plt.bar(city, count, color ='purple',width = 0.5)
 
plt.xlabel("City")
plt.ylabel("All Possible Victims")
plt.title("Kidnnaping")
plt.show()
